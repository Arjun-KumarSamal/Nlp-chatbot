# %%
import nltk
nltk.download('punkt')
nltk.download('wordnet')
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
import json
import pickle
import pandas as pd
import numpy as np
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout
from keras.optimizers import SGD
import random
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\arjun\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\arjun\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
with open("Intent.json") as diabetes_dataset:
  dataset = json.load(diabetes_dataset)

# %%
def processing_json_dataset(dataset):
  tags = []
  inputs = []
  responses={}
  for intent in dataset['intents']:
    responses[intent['intent']]=intent['responses']
    for lines in intent['text']:
      inputs.append(lines)
      tags.append(intent['intent'])
  return [tags, inputs, responses]

# %%
[tags, inputs, responses] = processing_json_dataset(dataset)

# %%
dataset = pd.DataFrame({"inputs":inputs,
                     "tags":tags})

# %%
dataset.sample(10)
# Out:
#                              inputs                      tags
# 35     What name do you call me by?         CurrentHumanQuery
# 28         Great thanks! I am Bella  CourtesyGreetingResponse
# 4                       Hello there                  Greeting
# 44   What is your real name please?             RealNameQuery
# 128                    Pod bay door                PodBayDoor
# 52     Do you know what time it is?                 TimeQuery
# 23        Good thanks! This is Adam  CourtesyGreetingResponse
# 82                             Shhh                    Shutup
# 21   Hello hope you are doing well?          CourtesyGreeting
# 60                           Thanks                    Thanks

# %%
words=[]
classes = []
documents = []
ignore_words = ['?', '!']
data_file = open('Intent.json', encoding='utf-8').read()
intents = json.loads(data_file)


for intent in intents['intents']:
    for pattern in intent['text']:

        w = nltk.word_tokenize(pattern)
        words.extend(w)

        documents.append((w, intent['intent']))


        if intent['intent'] not in classes:
            classes.append(intent['intent'])

words = [lemmatizer.lemmatize(w.lower()) for w in words if w not in ignore_words]
words = sorted(list(set(words)))

classes = sorted(list(set(classes)))

print (len(documents), "documents")

print (len(classes), "classes", classes)

print (len(words), "unique lemmatized words", words)
# Out:
# 143 documents
# 22 classes ['Clever', 'CourtesyGoodBye', 'CourtesyGreeting', 'CourtesyGreetingResponse', 'CurrentHumanQuery', 'GoodBye', 'Gossip', 'Greeting', 'GreetingResponse', 'Jokes', 'NameQuery', 'NotTalking2U', 'PodBayDoor', 'PodBayDoorResponse', 'RealNameQuery', 'SelfAware', 'Shutup', 'Swearing', 'Thanks', 'TimeQuery', 'UnderstandQuery', 'WhoAmI']
# 117 unique lemmatized words ["'s", ',', 'a', 'about', 'adam', 'adios', 'am', 'any', 'anyone', 'are', 'aware', 'bay', 'be', 'bella', 'bored', 'by', 'bye', 'call', 'camera', 'can', 'cheering', 'clever', 'communicating', 'comprendo', 'conscious', 'could', 'do', 'doing', 'door', 'enough', 'for', 'friend', 'fuck', 'genious', 'get', 'girl', 'give', 'good', 'goodbye', 'gossip', 'got', 'great', 'have', 'hear', 'hello', 'help', 'helpful', 'hi', 'hola', 'hope', 'how', 'hya', 'i', 'identify', 'in', 'intelligent', 'is', 'it', 'joke', 'know', 'later', 'laugh', 'make', 'me', 'mean', 'meant', 'more', 'my', "n't", 'name', 'need', 'not', 'off', 'ok', 'open', 'please', 'pod', 'prove', 'quiet', 'real', 'saying', 'see', 'self', 'self-aware', 'shhh', 'shit', 'shut', 'some', 'speaking', 'stop', 'surely', 'talking', 'tell', 'thank', 'thanks', 'that', 'the', 'there', 'think', 'this', 'time', 'to', 'twat', 'understand', 'up', 'user', 'very', 'wa', 'want', 'well', 'what', 'who', 'why', 'will', 'with', 'you', 'your']

# %%
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\arjun\AppData\Roaming\nltk_data...
# True

# %%
pickle.dump(words,open('words.pkl','wb'))
pickle.dump(classes,open('classes.pkl','wb'))

# initializing training data
training = []
output_empty = [0] * len(classes)
for doc in documents:

    bag = []

    pattern_words = doc[0]
    pattern_words = [lemmatizer.lemmatize(word.lower()) for word in pattern_words]

    for w in words:
        bag.append(1) if w in pattern_words else bag.append(0)


    output_row = list(output_empty)
    output_row[classes.index(doc[1])] = 1

    training.append([bag, output_row])

random.shuffle(training)
training = np.array(training)
# create train and test lists. X - patterns, Y - intents
train_x = list(training[:,0])
train_y = list(training[:,1])
print("Training data created")
# Out:
# Training data created
# C:\Users\arjun\AppData\Local\Temp\ipykernel_16908\572821790.py:24: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   training = np.array(training)

# %%
model = Sequential()
model.add(Dense(128, input_shape=(len(train_x[0]),), activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(len(train_y[0]), activation='softmax'))

# %%
sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])
# Out:
# C:\Users\arjun\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\optimizers\optimizer_v2\gradient_descent.py:108: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(SGD, self).__init__(name, **kwargs)

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 128)               15104
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense_2 (Dense)             (None, 22)                1430
#
# =================================================================
# Total params: 24,790
# Trainable params: 24,790
# Non-trainable params: 0
# _________________________________________________________________

# %%
hist = model.fit(np.array(train_x), np.array(train_y), epochs=200, batch_size=5, verbose=1)
# Out:
# Epoch 1/200
# 29/29 [==============================] - 1s 3ms/step - loss: 3.1164 - accuracy: 0.0420
# Epoch 2/200
# 29/29 [==============================] - 0s 3ms/step - loss: 3.0215 - accuracy: 0.0769
# Epoch 3/200
# 29/29 [==============================] - 0s 4ms/step - loss: 2.8981 - accuracy: 0.1748
# Epoch 4/200
# 29/29 [==============================] - 0s 4ms/step - loss: 2.6837 - accuracy: 0.2587
# Epoch 5/200
# 29/29 [==============================] - 0s 6ms/step - loss: 2.4995 - accuracy: 0.2867
# Epoch 6/200
# 29/29 [==============================] - 0s 4ms/step - loss: 2.3413 - accuracy: 0.3636
# Epoch 7/200
# 29/29 [==============================] - 0s 3ms/step - loss: 2.0194 - accuracy: 0.4895
# Epoch 8/200
# 29/29 [==============================] - 0s 4ms/step - loss: 1.9808 - accuracy: 0.4336
# Epoch 9/200
# 29/29 [==============================] - 0s 4ms/step - loss: 1.6936 - accuracy: 0.5035
# Epoch 10/200
# 29/29 [==============================] - 0s 3ms/step - loss: 1.6109 - accuracy: 0.5734
# Epoch 11/200
# 29/29 [==============================] - 0s 3ms/step - loss: 1.5123 - accuracy: 0.5315
# Epoch 12/200
# 29/29 [==============================] - 0s 4ms/step - loss: 1.3234 - accuracy: 0.5944
# Epoch 13/200
# 29/29 [==============================] - 0s 3ms/step - loss: 1.2058 - accuracy: 0.6084
# Epoch 14/200
# 29/29 [==============================] - 0s 3ms/step - loss: 1.1334 - accuracy: 0.6224
# Epoch 15/200
# 29/29 [==============================] - 0s 2ms/step - loss: 0.9238 - accuracy: 0.7273
# Epoch 16/200
# 29/29 [==============================] - 0s 3ms/step - loss: 1.0563 - accuracy: 0.6713
# Epoch 17/200
# 29/29 [==============================] - 0s 3ms/step - loss: 0.9667 - accuracy: 0.7413
# Epoch 18/200
# 29/29 [==============================] - 0s 3ms/step - loss: 0.8682 - accuracy: 0.7063
# Epoch 19/200
# 29/29 [==============================] - 0s 3ms/step - loss: 0.8096 - accuracy: 0.7273
# Epoch 20/200
# 29/29 [==============================] - 0s 4ms/step - loss: 0.9345 - accuracy: 0.7273
# Epoch 21/200
# 29/29 [==============================] - 0s 2ms/step - loss: 0.7352 - accuracy: 0.7692
# Epoch 22/200
# 29/29 [==============================] - 0s 3ms/step - loss: 0.5519 - accuracy: 0.8252
# Epoch 23/200
# 29/29 [==============================] - 0s 3ms/step - loss: 0.6833 - accuracy: 0.7762
# Epoch 24/200
# 29/29 [==============================] - 0s 2ms/step - loss: 0.5886 - accuracy: 0.8252
# Epoch 25/200
# 29/29 [==============================] - 0s 2ms/step - loss: 0.5856 - accuracy: 0.7972
# Epoch 26/200
# 29/29 [==============================] - 0s 3ms/step - loss: 0.4957 - accuracy: 0.8741
# Epoch 27/200
# 29/29 [==============================] - 0s 3ms/step - loss: 0.5144 - accuracy: 0.8462
# Epoch 28/200
# 29/29 [==============================] - 0s 2ms/step - loss: 0.4785 - accuracy: 0.8462
# Epoch 29/200
# 29/29 [==============================] - 0s 3ms/step - loss: 0.4789 - accuracy: 0.8741
# Epoch 30/200
# 29/29 [==============================] - 0s 3ms/step - loss: 0.4361 - accuracy: 0.8811
# Epoch 31/200
# 29/29 [==============================] - 0s 2ms/step - loss: 0.2730 - accuracy: 0.9441
# Epoch 32/200
# 29/29 [==============================] - 0s 2ms/step - loss: 0.3828 - accuracy: 0.8462
# Epoch 33/200
# 29/29 [==============================] - 0s 2ms/step - loss: 0.3423 - accuracy: 0.8951
# Epoch 34/200
# 29/29 [==============================] - 0s 2ms/step - loss: 0.3783 - accuracy: 0.9021
# Epoch 35/200
# 29/29 [==============================] - 0s 2ms/step - loss: 0.3198 - accuracy: 0.9161
# Epoch 36/200
# 29/29 [==============================] - 0s 2ms/step - loss: 0.2602 - accuracy: 0.9371
# Epoch 37/200
# 29/29 [==============================] - 0s 2ms/step - loss: 0.2867 - accuracy: 0.9371
# Epoch 38/200
# 29/29 [==============================] - 0s 2ms/step - loss: 0.3086 - accuracy: 0.9021
# Epoch 39/200
# 29/29 [==============================] - 0s 2ms/step - loss: 0.2971 - accuracy: 0.9021
# Epoch 40/200
# 29/29 [==============================] - 0s 2ms/step - loss: 0.2836 - accuracy: 0.9161
# Epoch 41/200
# 29/29 [==============================] - 0s 2ms/step - loss: 0.2706 - accuracy: 0.9371
# Epoch 42/200
# 29/29 [==============================] - 0s 2ms/step - loss: 0.2904 - accuracy: 0.8811
# Epoch 43/200
# 29/29 [==============================] - 0s 2ms/step - loss: 0.2856 - accuracy: 0.9021
# Epoch 44/200
# 29/29 [==============================] - 0s 3ms/step - loss: 0.2621 - accuracy: 0.9510
# Epoch 45/200
# 29/29 [==============================] - 0s 3ms/step - loss: 0.1663 - accuracy: 0.9650
# Epoch 46/200
# 29/29 [==============================] - 0s 4ms/step - loss: 0.2578 - accuracy: 0.9231
# Epoch 47/200
# 29/29 [==============================] - 0s 2ms/step - loss: 0.2295 - accuracy: 0.9371
# Epoch 48/200
# 29/29 [==============================] - 0s 2ms/step - loss: 0.2221 - accuracy: 0.9371
# Epoch 49/200
# 29/29 [==============================] - 0s 2ms/step - loss: 0.2418 - accuracy: 0.9021
# Epoch 50/200
# 29/29 [==============================] - 0s 3ms/step - loss: 0.1611 - accuracy: 0.9580
# Epoch 51/200
# 29/29 [==============================] - 0s 3ms/step - loss: 0.3761 - accuracy: 0.8601
# Epoch 52/200
# 29/29 [==============================] - 0s 2ms/step - loss: 0.2001 - accuracy: 0.9371
# Epoch 53/200
# 29/29 [==============================] - 0s 2ms/step - loss: 0.1806 - accuracy: 0.9720
# Epoch 54/200
# 29/29 [==============================] - 0s 2ms/step - loss: 0.2383 - accuracy: 0.9371
# Epoch 55/200
# 29/29 [==============================] - 0s 2ms/step - loss: 0.1548 - accuracy: 0.9790
# Epoch 56/200
# 29/29 [==============================] - 0s 2ms/step - loss: 0.2859 - accuracy: 0.8811
# Epoch 57/200
# 29/29 [==============================] - 0s 2ms/step - loss: 0.1945 - accuracy: 0.9371
# Epoch 58/200
# 29/29 [==============================] - 0s 3ms/step - loss: 0.1220 - accuracy: 0.9650
# Epoch 59/200
# 29/29 [==============================] - 0s 3ms/step - loss: 0.1870 - accuracy: 0.9301
# Epoch 60/200
# 29/29 [==============================] - 0s 2ms/step - loss: 0.1552 - accuracy: 0.9580
# Epoch 61/200
# 29/29 [==============================] - 0s 2ms/step - loss: 0.1921 - accuracy: 0.9091
# Epoch 62/200
# 29/29 [==============================] - 0s 5ms/step - loss: 0.2130 - accuracy: 0.9301
# Epoch 63/200
# 29/29 [==============================] - 0s 4ms/step - loss: 0.1354 - accuracy: 0.9510
# Epoch 64/200
# 29/29 [==============================] - 0s 3ms/step - loss: 0.1954 - accuracy: 0.9301
# Epoch 65/200
# 29/29 [==============================] - 0s 3ms/step - loss: 0.2013 - accuracy: 0.9441
# Epoch 66/200
# 29/29 [==============================] - 0s 3ms/step - loss: 0.1416 - accuracy: 0.9650
# Epoch 67/200
# 29/29 [==============================] - 0s 2ms/step - loss: 0.1622 - accuracy: 0.9510
# Epoch 68/200
# 29/29 [==============================] - 0s 3ms/step - loss: 0.2454 - accuracy: 0.9161
# Epoch 69/200
# 29/29 [==============================] - 0s 4ms/step - loss: 0.2227 - accuracy: 0.9371
# Epoch 70/200
# 29/29 [==============================] - 0s 2ms/step - loss: 0.1086 - accuracy: 0.9650
# Epoch 71/200
# 29/29 [==============================] - 0s 2ms/step - loss: 0.2336 - accuracy: 0.9231
# Epoch 72/200
# 29/29 [==============================] - 0s 2ms/step - loss: 0.1702 - accuracy: 0.9301
# Epoch 73/200
# 29/29 [==============================] - 0s 2ms/step - loss: 0.1675 - accuracy: 0.9441
# Epoch 74/200
# 29/29 [==============================] - 0s 3ms/step - loss: 0.1198 - accuracy: 0.9650
# Epoch 75/200
# 29/29 [==============================] - 0s 2ms/step - loss: 0.2136 - accuracy: 0.9650
# Epoch 76/200
# 29/29 [==============================] - 0s 2ms/step - loss: 0.1477 - accuracy: 0.9650
# Epoch 77/200
# 29/29 [==============================] - 0s 2ms/step - loss: 0.1098 - accuracy: 0.9720
# Epoch 78/200
# 29/29 [==============================] - 0s 2ms/step - loss: 0.1786 - accuracy: 0.9441
# Epoch 79/200
# 29/29 [==============================] - 0s 2ms/step - loss: 0.1162 - accuracy: 0.9580
# Epoch 80/200
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0714 - accuracy: 0.9650
# Epoch 81/200
# 29/29 [==============================] - 0s 3ms/step - loss: 0.1215 - accuracy: 0.9720
# Epoch 82/200
# 29/29 [==============================] - 0s 4ms/step - loss: 0.0854 - accuracy: 0.9720
# Epoch 83/200
# 29/29 [==============================] - 0s 3ms/step - loss: 0.1411 - accuracy: 0.9510
# Epoch 84/200
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0857 - accuracy: 0.9860
# Epoch 85/200
# 29/29 [==============================] - 0s 4ms/step - loss: 0.1007 - accuracy: 0.9720
# Epoch 86/200
# 29/29 [==============================] - 0s 4ms/step - loss: 0.1758 - accuracy: 0.9510
# Epoch 87/200
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0709 - accuracy: 0.9930
# Epoch 88/200
# 29/29 [==============================] - 0s 3ms/step - loss: 0.1139 - accuracy: 0.9790
# Epoch 89/200
# 29/29 [==============================] - 0s 4ms/step - loss: 0.1057 - accuracy: 0.9650
# Epoch 90/200
# 29/29 [==============================] - 0s 4ms/step - loss: 0.0753 - accuracy: 0.9790
# Epoch 91/200
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0948 - accuracy: 0.9790
# Epoch 92/200
# 29/29 [==============================] - 0s 4ms/step - loss: 0.0621 - accuracy: 0.9720
# Epoch 93/200
# 29/29 [==============================] - 0s 4ms/step - loss: 0.1122 - accuracy: 0.9510
# Epoch 94/200
# 29/29 [==============================] - 0s 4ms/step - loss: 0.0998 - accuracy: 0.9860
# Epoch 95/200
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0811 - accuracy: 0.9860
# Epoch 96/200
# 29/29 [==============================] - 0s 4ms/step - loss: 0.1513 - accuracy: 0.9441
# Epoch 97/200
# 29/29 [==============================] - 0s 4ms/step - loss: 0.1191 - accuracy: 0.9650
# Epoch 98/200
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0999 - accuracy: 0.9720
# Epoch 99/200
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0896 - accuracy: 0.9790
# Epoch 100/200
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0758 - accuracy: 0.9790
# Epoch 101/200
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0607 - accuracy: 0.9930
# Epoch 102/200
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0477 - accuracy: 0.9930
# Epoch 103/200
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0913 - accuracy: 0.9580
# Epoch 104/200
# 29/29 [==============================] - 0s 3ms/step - loss: 0.1655 - accuracy: 0.9441
# Epoch 105/200
# 29/29 [==============================] - 0s 3ms/step - loss: 0.1071 - accuracy: 0.9720
# Epoch 106/200
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0870 - accuracy: 0.9790
# Epoch 107/200
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0964 - accuracy: 0.9720
# Epoch 108/200
# 29/29 [==============================] - 0s 3ms/step - loss: 0.1158 - accuracy: 0.9720
# Epoch 109/200
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0959 - accuracy: 0.9650
# Epoch 110/200
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0628 - accuracy: 0.9860
# Epoch 111/200
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0600 - accuracy: 0.9790
# Epoch 112/200
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0526 - accuracy: 0.9860
# Epoch 113/200
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0540 - accuracy: 0.9930
# Epoch 114/200
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0596 - accuracy: 0.9860
# Epoch 115/200
# 29/29 [==============================] - 0s 4ms/step - loss: 0.0711 - accuracy: 0.9650
# Epoch 116/200
# 29/29 [==============================] - 0s 4ms/step - loss: 0.0855 - accuracy: 0.9790
# Epoch 117/200
# 29/29 [==============================] - 0s 4ms/step - loss: 0.0438 - accuracy: 0.9930
# Epoch 118/200
# 29/29 [==============================] - 0s 4ms/step - loss: 0.0879 - accuracy: 0.9790
# Epoch 119/200
# 29/29 [==============================] - 0s 4ms/step - loss: 0.0964 - accuracy: 0.9720
# Epoch 120/200
# 29/29 [==============================] - 0s 4ms/step - loss: 0.1170 - accuracy: 0.9720
# Epoch 121/200
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0468 - accuracy: 0.9930
# Epoch 122/200
# 29/29 [==============================] - 0s 4ms/step - loss: 0.0536 - accuracy: 0.9930
# Epoch 123/200
# 29/29 [==============================] - 0s 4ms/step - loss: 0.0997 - accuracy: 0.9580
# Epoch 124/200
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0487 - accuracy: 1.0000
# Epoch 125/200
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0326 - accuracy: 1.0000
# Epoch 126/200
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0844 - accuracy: 0.9860
# Epoch 127/200
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0481 - accuracy: 0.9790
# Epoch 128/200
# 29/29 [==============================] - 0s 3ms/step - loss: 0.1291 - accuracy: 0.9650
# Epoch 129/200
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0866 - accuracy: 0.9580
# Epoch 130/200
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0833 - accuracy: 0.9860
# Epoch 131/200
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0549 - accuracy: 0.9790
# Epoch 132/200
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0472 - accuracy: 1.0000
# Epoch 133/200
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0322 - accuracy: 1.0000
# Epoch 134/200
# 29/29 [==============================] - 0s 4ms/step - loss: 0.0507 - accuracy: 0.9860
# Epoch 135/200
# 29/29 [==============================] - 0s 4ms/step - loss: 0.0306 - accuracy: 0.9930
# Epoch 136/200
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0985 - accuracy: 0.9720
# Epoch 137/200
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0793 - accuracy: 0.9790
# Epoch 138/200
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0436 - accuracy: 0.9930
# Epoch 139/200
# 29/29 [==============================] - 0s 3ms/step - loss: 0.1167 - accuracy: 0.9650
# Epoch 140/200
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0578 - accuracy: 0.9720
# Epoch 141/200
# 29/29 [==============================] - 0s 3ms/step - loss: 0.1267 - accuracy: 0.9650
# Epoch 142/200
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0419 - accuracy: 0.9860
# Epoch 143/200
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0557 - accuracy: 0.9860
# Epoch 144/200
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0575 - accuracy: 0.9720
# Epoch 145/200
# 29/29 [==============================] - 0s 6ms/step - loss: 0.0480 - accuracy: 0.9860
# Epoch 146/200
# 29/29 [==============================] - 0s 4ms/step - loss: 0.0905 - accuracy: 0.9930
# Epoch 147/200
# 29/29 [==============================] - 0s 4ms/step - loss: 0.0681 - accuracy: 0.9650
# Epoch 148/200
# 29/29 [==============================] - 0s 4ms/step - loss: 0.0799 - accuracy: 0.9720
# Epoch 149/200
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0458 - accuracy: 0.9860
# Epoch 150/200
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0538 - accuracy: 0.9720
# Epoch 151/200
# 29/29 [==============================] - 0s 3ms/step - loss: 0.1332 - accuracy: 0.9720
# Epoch 152/200
# 29/29 [==============================] - 0s 3ms/step - loss: 0.1053 - accuracy: 0.9580
# Epoch 153/200
# 29/29 [==============================] - 0s 5ms/step - loss: 0.0808 - accuracy: 0.9720
# Epoch 154/200
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0708 - accuracy: 0.9790
# Epoch 155/200
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0542 - accuracy: 0.9790
# Epoch 156/200
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0348 - accuracy: 1.0000
# Epoch 157/200
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0700 - accuracy: 0.9650
# Epoch 158/200
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0537 - accuracy: 0.9860
# Epoch 159/200
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0434 - accuracy: 0.9860
# Epoch 160/200
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0740 - accuracy: 0.9790
# Epoch 161/200
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0270 - accuracy: 0.9930
# Epoch 162/200
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0217 - accuracy: 1.0000
# Epoch 163/200
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0800 - accuracy: 0.9650
# Epoch 164/200
# 29/29 [==============================] - 0s 4ms/step - loss: 0.0485 - accuracy: 0.9860
# Epoch 165/200
# 29/29 [==============================] - 0s 4ms/step - loss: 0.0255 - accuracy: 1.0000
# Epoch 166/200
# 29/29 [==============================] - 0s 7ms/step - loss: 0.0536 - accuracy: 0.9860
# Epoch 167/200
# 29/29 [==============================] - 0s 6ms/step - loss: 0.0969 - accuracy: 0.9650
# Epoch 168/200
# 29/29 [==============================] - 0s 5ms/step - loss: 0.0836 - accuracy: 0.9860
# Epoch 169/200
# 29/29 [==============================] - 0s 4ms/step - loss: 0.0374 - accuracy: 0.9930
# Epoch 170/200
# 29/29 [==============================] - 0s 4ms/step - loss: 0.0704 - accuracy: 0.9720
# Epoch 171/200
# 29/29 [==============================] - 0s 5ms/step - loss: 0.0780 - accuracy: 0.9790
# Epoch 172/200
# 29/29 [==============================] - 0s 4ms/step - loss: 0.0515 - accuracy: 0.9930
# Epoch 173/200
# 29/29 [==============================] - 0s 4ms/step - loss: 0.0510 - accuracy: 0.9930
# Epoch 174/200
# 29/29 [==============================] - 0s 5ms/step - loss: 0.0508 - accuracy: 0.9860
# Epoch 175/200
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0831 - accuracy: 0.9720
# Epoch 176/200
# 29/29 [==============================] - 0s 4ms/step - loss: 0.0941 - accuracy: 0.9650
# Epoch 177/200
# 29/29 [==============================] - 0s 5ms/step - loss: 0.0661 - accuracy: 0.9790
# Epoch 178/200
# 29/29 [==============================] - 0s 4ms/step - loss: 0.0307 - accuracy: 0.9860
# Epoch 179/200
# 29/29 [==============================] - 0s 4ms/step - loss: 0.0495 - accuracy: 0.9790
# Epoch 180/200
# 29/29 [==============================] - 0s 5ms/step - loss: 0.0577 - accuracy: 0.9860
# Epoch 181/200
# 29/29 [==============================] - 0s 4ms/step - loss: 0.0434 - accuracy: 0.9790
# Epoch 182/200
# 29/29 [==============================] - 0s 4ms/step - loss: 0.0477 - accuracy: 0.9860
# Epoch 183/200
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0514 - accuracy: 0.9860
# Epoch 184/200
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0497 - accuracy: 0.9720
# Epoch 185/200
# 29/29 [==============================] - 0s 4ms/step - loss: 0.0411 - accuracy: 0.9860
# Epoch 186/200
# 29/29 [==============================] - 0s 4ms/step - loss: 0.0165 - accuracy: 1.0000
# Epoch 187/200
# 29/29 [==============================] - 0s 5ms/step - loss: 0.0534 - accuracy: 0.9860
# Epoch 188/200
# 29/29 [==============================] - 0s 4ms/step - loss: 0.0596 - accuracy: 0.9860
# Epoch 189/200
# 29/29 [==============================] - 0s 4ms/step - loss: 0.0592 - accuracy: 0.9930
# Epoch 190/200
# 29/29 [==============================] - 0s 4ms/step - loss: 0.0252 - accuracy: 1.0000
# Epoch 191/200
# 29/29 [==============================] - 0s 4ms/step - loss: 0.0365 - accuracy: 0.9930
# Epoch 192/200
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0438 - accuracy: 0.9930
# Epoch 193/200
# 29/29 [==============================] - 0s 4ms/step - loss: 0.0212 - accuracy: 1.0000
# Epoch 194/200
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0811 - accuracy: 0.9790
# Epoch 195/200
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0528 - accuracy: 0.9860
# Epoch 196/200
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0179 - accuracy: 1.0000
# Epoch 197/200
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0200 - accuracy: 1.0000
# Epoch 198/200
# 29/29 [==============================] - 0s 5ms/step - loss: 0.0422 - accuracy: 0.9860
# Epoch 199/200
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0282 - accuracy: 1.0000
# Epoch 200/200
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0399 - accuracy: 0.9930

# %%
model.save('chatbot_model2.h5', hist)

# %%
print("model created")
# Out:
# model created
